# %%
import pandas as pd
import numpy as np
import os

# %%
df1=pd.read_excel("manuf_data.xlsx")
df1
# Out:
#      prod_id                             Description
# 0        355  Mexifiz Shampoo Intensive Repair 400ml
# 1        356  Mexifiz Shampoo Intensive Repair 400ml
# 2        381         Cbv Shampoo Moisture Rich 900ml
# 3        382         Cbv Shampoo Moisture Rich 900ml
# 4        426       Cbvery Hairspray Extra Hold 400ml
# ..       ...                                     ...
# 381     2589       Cbv Ro Mask Pump 200ml Dark Brown
# 382     2590     Cbv Ro Mask Pump 200ml Light Blonde
# 383     2591              Cbv Ro Mask Pump 200ml Red
# 384     2608          Cbv Inco Rinse Off Scrub 300ml
# 385     2644                 Fiur Gum Stick Tin 75ml
#
# [386 rows x 2 columns]

# %%
df1.shape
# Out:
# (386, 2)

# %%
df2=pd.read_excel("retailer_data.xlsx")
df2
# Out:
#      ret_prod_id                                Product_Description
# 0            188             Oddaced Give Me Moisture Shampoo 250ml
# 1            334                 Cbvery Freeze Hold Hairspray 400ml
# 2            328                   Cbvery Firm Hold Hairspray 400ml
# 3            203              Oddaced Ultimate Hold Hairspray 400ml
# 4            324                  Cbvery Extra Hold Hairspray 400ml
# ..           ...                                                ...
# 384          585  6Good Kind to Skin+ Protecting Moisture Cream ...
# 385          595  6Good Kind to Skin Vital Vitamin Day Cream SPF...
# 386          756       Toz Oil Infinite For Frizzy Hair Masque 190g
# 387          398  Twicebeaut Muru Muru Butter & Rose Blooming Co...
# 388          759        Toz Emergencée Masque For Damaged Hair 190g
#
# [389 rows x 2 columns]

# %%
df2.shape
# Out:
# (389, 2)

# %%
import os
for dirname, _, filenames in os.walk('ABC Product'):
    for filename in filenames:
        print(os.path.join(ABC_Product, df2,df1))

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ret_prod_id          389 non-null    int64
#  1   Product_Description  389 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 6.2+ KB

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
ev_count = df2["Product_Description"].value_counts()
ev_count
# Out:
# Parrot Adrenaline Iced Musk & Ginger Daily Fragrance 100ml                                                             1
# Mexifiz DEFI BARS Regular                                                                                              1
# 6Good Kind to Skin Cleansing ` Facial Wipes to lift impurities and make-up out 25 pc                                   1
# Toz Oil Infinite for Frizzy Hair Conditioner 250ml                                                                     1
# 6Good Kind to Hair Gentle Care with Pro-Vitamin B5 Hair Shampoo to restore and replenish your hair 200 ml pack of 6    1
#                                                                                                                       ..
# Cbvery Biotin+ Repair 7 Shampoo 400ml                                                                                  1
# Cbvery Expert Selection Botanique Nourish & Replenish Conditioner 500ml                                                1
# ...

# %%
def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} entry)".format(pct, absolute)
ax = ev_count.plot.pie(figsize=(6,6),radius=2,autopct=lambda pct: func(pct, ev_count),textprops=dict(color="w"),legend=True)
ax.legend(loc=2)

# %%
ABC = df2["ret_prod_id"].value_counts()
ABC.head()
# Out:
# 1023    1
# 687     1
# 733     1
# 145     1
# 146     1
# Name: ret_prod_id, dtype: int64

# %%
print('no. of products: ',len(df2))
print(df2.describe())
# Out:
# no. of products:  389
#        ret_prod_id
# count   389.000000
# mean    484.578406
# std     402.502740
# min       2.000000
# 25%     162.000000
# 50%     351.000000
# 75%     731.000000
# max    1617.000000

# %%
print('Top 10 Active Products')
print(df2.head(10))
# Out:
# Top 10 Active Products
#    ret_prod_id                     Product_Description
# 0          188  Oddaced Give Me Moisture Shampoo 250ml
# 1          334      Cbvery Freeze Hold Hairspray 400ml
# 2          328        Cbvery Firm Hold Hairspray 400ml
# 3          203   Oddaced Ultimate Hold Hairspray 400ml
# 4          324       Cbvery Extra Hold Hairspray 400ml
# 5          688      Oddaced Curl Defining Mousse 200ml
# 6          136      Cbvery Freeze Hold Hairspray 250ml
# 7          351           Mexifiz Pro Age Shampoo 400ml
# 8           95           Mexifiz Pro Age Shampoo 250ml
# 9          120               Sinoyez Wax Hair Wax 75ml

# %%
# %%HTML
# <style type="text/css">
#     table.dataframe td, table.dataframe th {
#         border-style: solid;
#     }
# </style>
# Out:
# <style type="text/css">
#     table.dataframe td, table.dataframe th {
#         border-style: solid;
#     }
# </style>

# %%
df2.plot.hist(bins=40,edgecolor="black",linewidth=2)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
category_dict=df2[['ret_prod_id','Product_Description']].drop_duplicates()
print('no. of category',len(df2['Product_Description'].drop_duplicates()))
counts=category_dict['Product_Description'].value_counts().sort_values(ascending=False)
print('Top 10 Category')
print(counts.head(10))
print('Last 10 Category')
print(counts.tail(10))
counts.plot.bar(logy=True)
# Out:
# no. of category 389
# Top 10 Category
# Cbvery HAIR CONDITIONER Keratin                                            1
# 6Good SKIN FACE SOS Clearing Booster                                       1
# Mexifiz Goodness-3 Skin Cream                                              1
# Mexifiz Clean Comfort Anti-perspirant Deodorant Roll On 50ml               1
# Cbvery Moisture Rich Conditioner 1.3ml                                     1
# Twicebeaut  Coconut Water & Mimosa Flower Hydro Gel 250 ML                 1
# Parrot Black Trio Body Wash, Spray and Anti-Perspirant 3 Piece Gift Set    1
# 6Good Spotless Skin Triple Action Face Wash 150ml                          1
# Cbvery Beauty-Full Volume Shampoo 400ml                                    1
# Mexifiz Intensive Body Lotion 400ml                                        1
# Name: Product_Description, dtype: int64
# Last 10 Category
# 6Good Regeneration Age Resisting SPF15 Day Cream to defend skin from early signs of ageing 50ml    1
# ...

# %%
#So we're down to five lets see the transaction of each product
print(df2.loc[df2['ret_prod_id']==188][['Product_Description']])
print(df2.loc[df2['ret_prod_id']==328][['Product_Description']])
print(df2.loc[df2['ret_prod_id']==334][['Product_Description']])
print(df2.loc[df2['ret_prod_id']==688][['Product_Description']])
print(df2.loc[df2['ret_prod_id']==351][['Product_Description']])
# Out:
#                       Product_Description
# 0  Oddaced Give Me Moisture Shampoo 250ml
#                 Product_Description
# 2  Cbvery Firm Hold Hairspray 400ml
#                   Product_Description
# 1  Cbvery Freeze Hold Hairspray 400ml
#                   Product_Description
# 5  Oddaced Curl Defining Mousse 200ml
#              Product_Description
# 7  Mexifiz Pro Age Shampoo 400ml

# %%
df2.isnull()
# Out:
#      ret_prod_id  Product_Description
# 0          False                False
# 1          False                False
# 2          False                False
# 3          False                False
# 4          False                False
# ..           ...                  ...
# 384        False                False
# 385        False                False
# 386        False                False
# 387        False                False
# 388        False                False
#
# [389 rows x 2 columns]
